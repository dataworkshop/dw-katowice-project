# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import time
from sklearn.cluster import DBSCAN
from typing import List
import re

from tqdm import tqdm
from joblib import Parallel, delayed

# %%
df = pd.read_csv('../wypadek.csv')

# %%
df.sample(2)
# Out:
#        Data zdarzenia   Godzina      GPS x      GPS y Miejscowość       Ulica  \
# 172800     2019-01-24  19:00:00  18*31'366  49*57'412      MSZANA         NaN
# 97331      2017-10-12  14:35:00  18*56'459  49*58'271    PSZCZYNA  KOŚCIUSZKI
#
#        Numer domu Numer drogi KM HM (Pikietaż)                Obszar  ...  \
# 172800        NaN         A1A               40  Obszar niezabudowany  ...
# 97331         NaN    G340251S              NaN     Obszar zabudowany  ...
#
#        Sygnalizacja świetlna Oznakowanie poziome Liczba pasów w zdarzeniu  \
# 172800                  Brak                Jest                      1.0
# 97331                   Brak                Jest                      NaN
#
#          Zachowanie kierującego Zachowanie pieszego Inne przyczyny  \
# 172800                      NaN                 NaN    Stan jezdni
# 97331   Nieprawidłowe skręcanie                 NaN            NaN
#
#        Liczba rannych w zdarzeniu Liczba zabitych w zdarzeniu Liczba kolizji  \
# 172800                          0                           0              1
# 97331                           0                           0              1
#
#        Liczba wypadków
# 172800               0
# 97331                0
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Usuwanie wierszy w złym formacje danych:

# %% [markdown]
# df['y_counter'] = df['GPS y'].apply(lambda x: x.count('*'))
# df['x_counter'] = df['GPS x'].apply(lambda x: x.count('*'))
# df = df[(df['y_counter'] < 2) & (df['x_counter'] < 2)]
# df = df.drop(columns=['y_counter', 'x_counter'])

# %% [markdown]
# ### Konwersja stopnii, minut (dm) na stopnie dziesiętne (dd):

# %% [markdown]
# def dm_to_dd(dm):
#     deg, minutes = re.split('[*]', dm)
#     minutes = minutes.replace("'", '.')
#     minutes = float(re.sub("[.]{2,}", '.', minutes))
#     return (float(deg) + float(minutes)/60)
#
# def dm_converter(source_columns: List[str], target_columns: List[str], data_frame: DataFrame):
#     for source, target in zip(source_columns, target_columns):
#         data_frame[target] = data_frame[source].apply(lambda x: round(dm_to_dd(x), 6))
#     return data_frame

# %% [markdown]
# df = dm_converter(source_columns=['GPS y', 'GPS x'], target_columns=['Lat', 'Lon'], data_frame=df)
# df.head(2)

# %% [markdown]
# ### Konwersja HH.MM.SS.S -> DD (Michał):

# %%
# https://stackoverflow.com/questions/33997361
def dms2dd(coord):
    """ GPS HH.MM.SS.S to DD (Decimal Degrees) conversion """
    c = re.findall(r"\w+", coord)
    degrees = float(c[0])
    minutes = float(c[1])
    if len(c) > 2:
        seconds = float(c[2])/10   
    else:
        seconds = 0
    
    dd = float(degrees) + (minutes)/60 + float(seconds)/(60*60)

    return dd

df['Lat'] = df['GPS y'].apply(lambda x : round(dms2dd(x), 6)) # Latitude - N
df['Lon'] = df['GPS x'].apply(lambda x : round(dms2dd(x), 6)) # Longitude - E

# %%
df.head()
# Out:
#   Data zdarzenia   Godzina      GPS x      GPS y       Miejscowość  \
# 0     2016-01-01  05:15:00  18*38'089  50*22'110           GLIWICE
# 1     2016-01-01  00:05:00  19*10'510  50*19'231  DĄBROWA GÓRNICZA
# 2     2016-01-01  18:30:00  18*52'395  50*26'423   TARNOWSKIE GÓRY
# 3     2016-01-01  15:10:00  18*51'381  50*26'408   TARNOWSKIE GÓRY
# 4     2016-01-01  17:45:00  19*02'512  50*28'005         OŻAROWICE
#
#                  Ulica Numer domu Numer drogi KM HM (Pikietaż)  \
# 0             TOSZECKA        NaN         901             61,6
# 1         SIENKIEWICZA        NaN   G200 030S              NaN
# 2    KS.IGNACEGO SIWCA         4A      GMINNA              NaN
# 3  JÓZEFA PIŁSUDSKIEGO          6      P3276S              NaN
# 4             DWORCOWA         16      P3203S              NaN
#
#                  Obszar  ... Liczba pasów w zdarzeniu  \
# 0  Obszar niezabudowany  ...                      2.0
# 1     Obszar zabudowany  ...                      NaN
# 2     Obszar zabudowany  ...                      2.0
# 3     Obszar zabudowany  ...                      2.0
# 4     Obszar zabudowany  ...                      2.0
#
#     Zachowanie kierującego Zachowanie pieszego                Inne przyczyny  \
# 0                      NaN                 NaN  Obiekty, zwierzęta na drodze
# 1   Nieprawidłowe: cofanie                 NaN                           NaN
# 2  Nieprawidłowe: omijanie                 NaN                           NaN
# 3  Nieprawidłowe: omijanie                 NaN                           NaN
# 4                      NaN                 NaN  Obiekty, zwierzęta na drodze
#
#   Liczba rannych w zdarzeniu Liczba zabitych w zdarzeniu Liczba kolizji  \
# 0                          0                           0              1
# 1                          0                           0              1
# 2                          0                           0              1
# 3                          0                           0              1
# 4                          0                           0              1
#
#   Liczba wypadków        Lat        Lon
# 0               0  50.369722  18.635806
# 1               0  50.323083  19.180833
# 2               0  50.445083  18.877639
# 3               0  50.444667  18.860583
# 4               0  50.466806  19.047556
#
# [5 rows x 32 columns]

# %% [markdown]
# ## GRUPOWANIE DANYCH - algorytm DBSCAN:
# https://geoffboeing.com/2014/08/clustering-to-reduce-spatial-data-set-size/

# %% [markdown]
# ### Obliczenia na jednym wątku:

# %%
def dbscan_lat_lon(data_frame: DataFrame, distance=50):
    start_time = time.time() 
    
    kms_per_radian = 6371.0088
    coords = data_frame.loc[:,['Lat', 'Lon']].values
    epsilon = (distance / 1000) / kms_per_radian
    
    dbscan = DBSCAN(eps=epsilon, 
                    min_samples=1, 
                    algorithm='ball_tree', 
                    metric='haversine')
    
    db = dbscan.fit(np.radians(coords))

    a = pd.DataFrame(data_frame, columns=data_frame.columns)
    a.reset_index(drop=True, inplace=True)
    b = pd.DataFrame(db.labels_, columns=['DBSCAN_Lat_Lon'])
    b.reset_index(drop=True, inplace=True)
   
    
    cluster_labels = db.labels_
    num_start_point = len(data_frame)
    num_clusters = len(set(cluster_labels)) 
    proc_compression = 100 * (1 - float(num_clusters) / num_start_point)
    print(f'Clustered {len(data_frame):,} points down to {num_clusters:,} clusters, '
          f'for {proc_compression:,.2f}% compression.') 
    end_time = time.time()

    print('Calculate time: {:,.2f} seconds'.format(end_time - start_time)) 
    return pd.concat([a,b], axis=1)

# %%
result = dbscan_lat_lon(distance=50, data_frame=df)

# %% [markdown]
# ### Grupy najczęściej występjące:

# %%
result.groupby(['Miejscowość', 'DBSCAN_Lat_Lon'])['DBSCAN_Lat_Lon'].count().sort_values(ascending=False).head(10)

# %%
result[(result['DBSCAN_Lat_Lon'] == 5539) & (result['Miejscowość'] == 'KATOWICE')].sort_values(by='Lat').head(10)

# %% [markdown]
# ### Obliczenia wielowątkowe:

# %%
distance = 50
chunk = 'Miejscowość'

kms_per_radian = 6371.0088
epsilon = (distance / 1000)/ kms_per_radian


def dbscan_lat_lon(i):
    
    temp_df = df[df[chunk] == i]
    np_array_dict = dataframe_to_arrays(temp_df.columns, temp_df)
    
    dbscan = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine')
    db = dbscan.fit(coords_to_radians(df, i))
    return np.c_[np.array(list(np_array_dict.values())).transpose(), db.labels_]

def dataframe_to_arrays(columns: List[str], df):
    np_array_dict = {}
    for j in list(columns):
        np_array_dict[j] = df[j].values.astype('U')
    return np_array_dict

def coords_to_radians(df, i):
    coords = np.radians(df.loc[:, ['Lat', 'Lon']].values [df[chunk] == i])
    return coords

results = Parallel(n_jobs=-1, verbose=10, backend = 'multiprocessing')(delayed(dbscan_lat_lon)(i) for i in tqdm(np.unique(df[chunk].values)))

data_frame_columns_name = list(df.columns)
results = DataFrame(np.concatenate([a for a in results], axis=0),
                    columns=(data_frame_columns_name + list(['DBSCAN_Lat_Lon'])))
# Out:
#   0%|          | 0/1097 [00:00<?, ?it/s][Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 8 concurrent workers.
#   0%|          | 1/1097 [00:00<06:19,  2.89it/s][Parallel(n_jobs=-1)]: Batch computation too fast (0.0802s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
#   2%|▏         | 20/1097 [00:00<04:22,  4.10it/s][Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.2s
#  10%|█         | 111/1097 [00:00<01:28, 11.10it/s][Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.7s
#  13%|█▎        | 144/1097 [00:01<00:47, 19.94it/s][Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    1.1s
#  17%|█▋        | 184/1097 [00:02<00:27, 33.03it/s][Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:    2.1s
#  20%|██        | 224/1097 [00:03<00:33, 25.95it/s][Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    3.4s
#  26%|██▌       | 281/1097 [00:04<00:21, 38.29it/s][Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:    4.5s
#  27%|██▋       | 296/1097 [00:05<00:20, 38.30it/s][Parallel(n_jobs=-1)]: Batch computation too slow (2.0020s.) Setting batch_size=2.
#  28%|██▊       | 310/1097 [00:06<01:04, 12.17it/s][Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    6.6s
#  32%|███▏      | 348/1097 [00:08<00:39, 18.93it/s][Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:    8.0s
#  34%|███▍      | 378/1097 [00:09<00:26, 27.57it/s][Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:    9.1s
#  37%|███▋      | 404/1097 [00:09<00:18, 37.19it/s][Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:    9.9s
#  39%|███▉      | 432/1097 [00:12<01:02, 10.58it/s][Parallel(n_jobs=-1)]: Batch computation too slow (2.0310s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   12.6s
#  42%|████▏     | 457/1097 [00:13<00:24, 25.61it/s][Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:   13.1s
#  43%|████▎     | 476/1097 [00:13<00:15, 41.08it/s][Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:   13.3s
#  46%|████▌     | 500/1097 [00:14<00:13, 45.27it/s][Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:   13.9s
#  47%|████▋     | 518/1097 [00:14<00:11, 50.15it/s][Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:   14.2s
#  49%|████▉     | 542/1097 [00:14<00:10, 50.52it/s][Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:   14.6s
#  52%|█████▏    | 566/1097 [00:15<00:15, 34.14it/s][Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed:   15.4s
#  54%|█████▍    | 591/1097 [00:16<00:11, 45.34it/s][Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed:   15.8s
#  56%|█████▌    | 614/1097 [00:16<00:11, 43.65it/s][Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed:   16.4s
#  59%|█████▊    | 644/1097 [00:17<00:12, 34.90it/s][Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed:   17.2s
#  61%|██████    | 667/1097 [00:18<00:09, 44.66it/s][Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed:   17.8s
#  64%|██████▍   | 700/1097 [00:18<00:09, 40.90it/s][Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed:   18.6s
#  66%|██████▌   | 725/1097 [00:19<00:08, 44.61it/s][Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:   19.2s
#  69%|██████▉   | 759/1097 [00:20<00:08, 38.12it/s][Parallel(n_jobs=-1)]: Done 745 tasks      | elapsed:   20.1s
#  72%|███████▏  | 790/1097 [00:21<00:09, 32.37it/s][Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:   21.2s
#  75%|███████▍  | 820/1097 [00:23<00:10, 25.47it/s][Parallel(n_jobs=-1)]: Done 809 tasks      | elapsed:   22.8s
#  78%|███████▊  | 853/1097 [00:23<00:05, 43.01it/s][Parallel(n_jobs=-1)]: Done 842 tasks      | elapsed:   23.5s
#  81%|████████  | 890/1097 [00:24<00:04, 46.28it/s][Parallel(n_jobs=-1)]: Done 877 tasks      | elapsed:   24.3s
#  84%|████████▍ | 924/1097 [00:25<00:05, 29.20it/s][Parallel(n_jobs=-1)]: Done 912 tasks      | elapsed:   25.7s
#  88%|████████▊ | 964/1097 [00:27<00:05, 23.48it/s][Parallel(n_jobs=-1)]: Done 949 tasks      | elapsed:   27.0s
#  91%|█████████ | 995/1097 [00:30<00:09, 10.46it/s][Parallel(n_jobs=-1)]: Done 987 tasks      | elapsed:   30.4s
#  95%|█████████▍| 1038/1097 [00:31<00:01, 39.72it/s][Parallel(n_jobs=-1)]: Done 1026 tasks      | elapsed:   31.2s
#  98%|█████████▊| 1074/1097 [00:32<00:00, 43.13it/s][Parallel(n_jobs=-1)]: Done 1065 tasks      | elapsed:   32.0s
# 100%|██████████| 1097/1097 [00:32<00:00, 33.56it/s]
# [Parallel(n_jobs=-1)]: Done 1097 out of 1097 | elapsed:   33.9s finished

# %% [markdown]
# ### Grupy najczęściej występjące:

# %%
results.head(6)
# Out:
#   Data zdarzenia   Godzina      GPS x      GPS y Miejscowość     Ulica  \
# 0     2016-03-14  06:35:00  18*19'234  50*07'494   ADAMOWICE  RYBNICKA
# 1     2016-05-19  18:45:00  18*20'455  50*07'493   ADAMOWICE  RYBNICKA
# 2     2017-07-07  18:30:00  18*20'474  50*07'491   ADAMOWICE  RYBNICKA
# 3     2019-05-21  15:10:00  18*20'249  50*07'522   ADAMOWICE  RYBNICKA
# 4     2019-06-17  10:50:00  18*19'232  50*07'492   ADAMOWICE  RYBNICKA
# 5     2019-09-06  12:40:00  18*21'118  50*07'559   ADAMOWICE  RYBNICKA
#
#   Numer domu Numer drogi KM HM (Pikietaż)                Obszar  ...  \
# 0        nan      P5604S              nan  Obszar niezabudowany  ...
# 1         82      P5604S              nan     Obszar zabudowany  ...
# 2         81      P5604S              nan  Obszar niezabudowany  ...
# 3        76B      P5604S              nan     Obszar zabudowany  ...
# 4        nan      P5604S              nan  Obszar niezabudowany  ...
# 5        nan      P5604S              nan  Obszar niezabudowany  ...
#
#                         Zachowanie kierującego Zachowanie pieszego  \
# 0                                          nan                 nan
# 1  Niedostosowanie prędkości do warunków ruchu                 nan
# 2                                          nan                 nan
# 3                               Inne przyczyny                 nan
# 4                                          nan                 nan
# 5                       Nieprawidłowe omijanie                 nan
#
#                  Inne przyczyny Liczba rannych w zdarzeniu  \
# 0  Obiekty, zwierzęta na drodze                          0
# 1                           nan                          0
# 2                          Inne                          0
# 3                           nan                          0
# 4  Obiekty, zwierzęta na drodze                          0
# 5                           nan                          0
#
#   Liczba zabitych w zdarzeniu Liczba kolizji Liczba wypadków        Lat  \
# 0                           0              1               0  50.130389
# 1                           0              1               0  50.130361
# 2                           0              1               0  50.130306
# 3                           0              1               0  50.131167
# 4                           0              1               0  50.130333
# 5                           0              1               0  50.132194
#
#          Lon DBSCAN_Lat_Lon
# 0  18.323167              0
# 1  18.345972              1
# 2    18.3465              1
# 3   18.34025              2
# 4  18.323111              0
# 5  18.353278              3
#
# [6 rows x 33 columns]

# %%
results.groupby(['Miejscowość', 'DBSCAN_Lat_Lon'])['DBSCAN_Lat_Lon'].count().sort_values(ascending=False).head(10)
# Out:
# Miejscowość    DBSCAN_Lat_Lon
# KATOWICE       5                 14336
# CZĘSTOCHOWA    5                  4301
# GLIWICE        8                  2344
# BIELSKO-BIAŁA  14                 1860
# BYTOM          0                  1499
# SOSNOWIEC      2                  1232
# ZABRZE         4                   982
# CZĘSTOCHOWA    17                  935
#                1                   828
# RYBNIK         22                  799
# Name: DBSCAN_Lat_Lon, dtype: int64

# %%
results[(results['DBSCAN_Lat_Lon'] == '5') & (results['Miejscowość'] == 'KATOWICE')].sort_values(by='Lat').head(10)
# Out:
#        Data zdarzenia   Godzina      GPS x      GPS y Miejscowość  \
# 101723     2017-10-22  16:25:00  19*03'133  50*14'222    KATOWICE
# 102577     2017-12-01  14:45:00  19*03'103  50*14'228    KATOWICE
# 117077     2019-12-26  18:00:00  19*03'094  50*14'228    KATOWICE
# 107315     2018-08-26  11:10:00  19*03'084  50*14'229    KATOWICE
# 98619      2017-04-29  04:45:00  19*03'095  50*14'229    KATOWICE
# 98527      2017-04-26  15:20:00  19*03'096  50*14'229    KATOWICE
# 112657     2019-05-15  16:00:00  19*03'088  50*14'230    KATOWICE
# 112628     2019-05-15  07:40:00  19*03'099  50*14'230    KATOWICE
# 115854     2019-11-04  07:45:00  19*03'091  50*14'230    KATOWICE
# 100369     2017-08-19  23:20:00  19*03'096  50*14'230    KATOWICE
#
#               Ulica Numer domu Numer drogi KM HM (Pikietaż)  \
# 101723   PSZCZYŃSKA        nan          86              nan
# 102577  GÓRNOŚLĄSKA        nan    G100446S              nan
# 117077  GÓRNOŚLĄSKA        nan    G100446S              nan
# 107315   MURCKOWSKA        nan          86              nan
# 98619           nan        nan          A4            340,3
# 98527   GÓRNOŚLĄSKA        nan    G100446S              nan
# 112657  GÓRNOŚLĄSKA        nan    G100446S              nan
# 112628  GÓRNOŚLĄSKA        nan    G100446S              nan
# 115854  GÓRNOŚLĄSKA        nan    G100446S              nan
# 100369  GÓRNOŚLĄSKA        nan    G100466S              nan
#
#                       Obszar  ...  \
# 101723  Obszar niezabudowany  ...
# 102577  Obszar niezabudowany  ...
# 117077  Obszar niezabudowany  ...
# 107315  Obszar niezabudowany  ...
# 98619   Obszar niezabudowany  ...
# 98527   Obszar niezabudowany  ...
# 112657  Obszar niezabudowany  ...
# 112628  Obszar niezabudowany  ...
# 115854  Obszar niezabudowany  ...
# 100369  Obszar niezabudowany  ...
#
#                              Zachowanie kierującego Zachowanie pieszego  \
# 101723                                          nan                 nan
# 102577          Nieprawidłowe zmienianie pasa ruchu                 nan
# 117077  Niedostosowanie prędkości do warunków ruchu                 nan
# 107315  Niedostosowanie prędkości do warunków ruchu                 nan
# 98619   Niedostosowanie prędkości do warunków ruchu                 nan
# 98527   Niedostosowanie prędkości do warunków ruchu                 nan
# 112657  Niedostosowanie prędkości do warunków ruchu                 nan
# 112628          Nieprawidłowe zmienianie pasa ruchu                 nan
# 115854  Niedostosowanie prędkości do warunków ruchu                 nan
# 100369  Niedostosowanie prędkości do warunków ruchu                 nan
#
#        Inne przyczyny Liczba rannych w zdarzeniu Liczba zabitych w zdarzeniu  \
# 101723    Nieustalone                          0                           0
# 102577            nan                          0                           0
# 117077            nan                          0                           0
# 107315            nan                          0                           0
# 98619             nan                          0                           0
# 98527             nan                          0                           0
# 112657            nan                          2                           0
# 112628            nan                          0                           0
# 115854            nan                          0                           0
# 100369            nan                          0                           0
#
#        Liczba kolizji Liczba wypadków        Lat        Lon DBSCAN_Lat_Lon
# 101723              1               0    50.2395  19.053694              5
# 102577              1               0  50.239667  19.052861              5
# 117077              1               0  50.239667  19.052611              5
# 107315              1               0  50.239694  19.052333              5
# 98619               1               0  50.239694  19.052639              5
# 98527               1               0  50.239694  19.052667              5
# 112657              0               1  50.239722  19.052444              5
# 112628              1               0  50.239722   19.05275              5
# 115854              1               0  50.239722  19.052528              5
# 100369              1               0  50.239722  19.052667              5
#
# [10 rows x 33 columns]
