# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
#import dataset
wyp2018 = pd.read_csv('../../dane/wyp2018_enriched.csv')
pog2018 = pd.read_csv('../../dane/pogoda_2018.csv')

# %%
#deal with missing values

#check what is missing
pog2018.eq(999.9).sum()
# Out:
# daynumber     0
# dayofweek     0
# meantemp      0
# visib        40
# wdsp          0
# fog           0
# prcp          0
# dtype: int64

# %%
#fill with avg value from column

for index,value in pog2018.iterrows():
    if pog2018['visib'][index] == 999.9:
        pog2018['visib'][index] = pog2018[pog2018['visib'] != 999.9]['visib'].mean()
# Out:
# C:\Users\acibis\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#convert to metric values
pog2018['meantemp'] = ((pog2018['meantemp']-32)*5)/9 #Farenheit to Celsius
pog2018['prcp'] = pog2018['prcp']*25.4               # inches to l/m^2
pog2018['wdsp'] = pog2018['wdsp']*0.51               # knots to m/s
pog2018['visib'] = pog2018['visib']*1609             # miles to meters

# %%
#merge datasets
df = pd.merge(wyp2018, pog2018, left_on='daynumber', right_on='daynumber')

# %%
#is there any correlation between number of rentals and the weather?
#let's create small df

#how many rentals per day?
rd = df.groupby(['month_day'])['bike_num'].count()

#avg temp
avg_temp = df.groupby(['month_day'])['meantemp'].mean().values

#precipitation
prp = df.groupby(['month_day'])['prcp'].mean().values

#wind speed
ws = df.groupby(['month_day'])['wdsp'].mean().values

#visibility
vis = df.groupby(['month_day'])['visib'].mean().values

#fog
fog = df.groupby(['month_day'])['fog'].mean().values

data = pd.DataFrame(data={'date' : rd.index, 'rentals_number' : rd.values,
                          'avg_temp' : avg_temp, 'precipitation' : prp,
                          'wind_speed' : ws, 'visibility' : vis, 'fog' : fog})

corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col1 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col4 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row0_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col0 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col4 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row1_col5 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col4 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row2_col5 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col2 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col4 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row3_col5 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col0 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col1 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col2 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col3 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col2 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c732b550_1ccd_11ea_bfd7_106530649879row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_c732b550_1ccd_11ea_bfd7_106530649879" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rentals_number</th>        <th class="col_heading level0 col1" >avg_temp</th>        <th class="col_heading level0 col2" >precipitation</th>        <th class="col_heading level0 col3" >wind_speed</th>        <th class="col_heading level0 col4" >visibility</th>        <th class="col_heading level0 col5" >fog</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c732b550_1ccd_11ea_bfd7_106530649879level0_row0" class="row_heading level0 row0" >rentals_number</th>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col1" class="data row0 col1" >0.784425</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col2" class="data row0 col2" >-0.170979</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col3" class="data row0 col3" >-0.30756</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col4" class="data row0 col4" >0.338949</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row0_col5" class="data row0 col5" >-0.144224</td>
#             </tr>
#             <tr>
#                         <th id="T_c732b550_1ccd_11ea_bfd7_106530649879level0_row1" class="row_heading level0 row1" >avg_temp</th>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col0" class="data row1 col0" >0.784425</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col2" class="data row1 col2" >0.0208911</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col3" class="data row1 col3" >-0.245463</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col4" class="data row1 col4" >0.353246</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row1_col5" class="data row1 col5" >-0.149057</td>
#             </tr>
#             <tr>
#                         <th id="T_c732b550_1ccd_11ea_bfd7_106530649879level0_row2" class="row_heading level0 row2" >precipitation</th>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col0" class="data row2 col0" >-0.170979</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col1" class="data row2 col1" >0.0208911</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col3" class="data row2 col3" >0.14965</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col4" class="data row2 col4" >-0.0388333</td>
#                         <td id="T_c732b550_1ccd_11ea_bfd7_106530649879row2_col5" class="data row2 col5" >-0.0266742</td>
#             </tr>
#             <tr>
#                         <th id=

# %%
from plotly.subplots import make_subplots
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=data['date'], y=data['rentals_number'], name="rentals_number"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=data['date'], y=data['avg_temp'], name="avg_temp"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Number of rentals vs average temperature"
)

# Set x-axis title
fig.update_xaxes(title_text="date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> rentals number", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> avg temp", secondary_y=True)

fig.show()
# Out:
# <div>
#
#
#             <div id="575781ee-1cc5-4f57-81a8-3b15c849aa16" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("575781ee-1cc5-4f57-81a8-3b15c849aa16")) {
#                     Plotly.newPlot(
#                         '575781ee-1cc5-4f57-81a8-3b15c849aa16',
#                         [{"name": "rentals_number", "type": "scatter", "x": ["2018-04-01", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-07", "2018-04-08", "2018-04-09", "2018-04-10", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-14", "2018-04-15", "2018-04-16", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-21", "2018-04-22", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-28", "2018-04-29", "2018-04-30", "2018-05-01", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-12", "2018-05-13", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-19", "2018-05-20", "2018-05-21", "2018-05-22", "2018-05-23", "2018-05-24", "2018-05-25", "2018-05-26", "2018-05-27", "2018-05-28", "2018-05-29", "2018-05-30", "2018-05-31", "2018-06-01", "2018-06-02", "2018-06-03", "2018-06-04", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2018-06-09", "2018-06-10", "2018-06-11", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-17", "2018-06-18", "2018-06-19", "2018-06-20", "2018-06-21", "2018-06-22", "2018-06-23", "2018-06-24", "2018-06-25", "2018-06-26", "2018-06-27", "2018-06-28", "2018-06-29", "2018-06-30", "2018-07-01", "2018-07-02", "2018-07-03", "2018-07-04", "2018-07-05", "2018-07-06", "2018-07-07", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-14", "2018-07-15", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-21", "2018-07-22", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-28", "2018-07-29", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-04", "2018-08-05", "2018-08-06", "2018-08-07", "2018-08-08", "2018-08-09", "2018-08-10", "2018-08-11", "2018-08-12", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-17", "2018-08-18", "2018-08-19", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-24", "2018-08-25", "2018-08-26", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-08-31", "2018-09-01", "2018-09-02", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-09", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-16", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-22", "2018-09-23", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-09-29", "2018-09-30", "2018-10-01", "2018-10-02", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-13", "2018-10-14", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-18", "2018-10-19", "2018-10-20", "2018-10-21", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-27", "2018-10-28", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-03", "2018-11-04", "2018-11-05", "2018-11-06", "2018-11-07", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-12", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-29", "2018-11-30", "2018-12-01", "2018-12-02", "2018-12-03", "2018-12-04", "2018-12-05", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-09", "2018-12-10", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-15", "2018-12-16"], "xaxis": "x", "y": [47, 280, 513, 542, 721, 603, 938, 1103, 1067, 1043, 1047, 1287, 937, 1459, 1403, 472, 952, 1269, 1328, 1287, 1261, 1399, 713, 1016, 1026, 631, 872, 1022, 889, 891, 1354, 876, 1041, 955, 1153, 1152, 1081, 740, 918, 1114, 636, 998, 1287, 921, 546, 629, 111, 404, 912, 1046, 916, 1089, 753, 980, 1062, 948, 1013, 1029, 980, 1003, 1440, 1164, 719, 91 ...
